# %%
# -*- coding: utf8 -*-
import sys
sys.path.insert(1,'../')
#tried to do the whole "..package_dir.module" thing but kept getting a relative import error I
#could not fix by putting '__init___.py' files everywhere which is what I did to try and to fix this

# %%
import os
import json
from astropy.io import fits
from astropy import units
import glob
import pandas as pd
import numpy as np
import ccdproc
from ccdproc import CCDData
import warnings
warnings.filterwarnings('ignore')
import logging
import argparse
import logging
from importlib import reload
from SAMOS_DRP.SAMOSHelpers import load_bucket_status,save_bucket_status
from SAMOS_DRP.Spectroscopy.wavelength import WavelengthCalibration
from SAMOS_DRP.DoWavecal import WaveCalBuckets

# %% [markdown]
# # INITIALIZATION
#
#
# Step 1: organize the data and stores relevant information based on FITS headers.
#
#
# Observation information is organized into a main `pandas.DataFrame` called a `night_bucket` because it contains all the data for a particular night of observations.  This bucket object is further divided into the following main data reduction buckets:
# <h3> Bias frames:</h3> not currently useful because bias in the Goodman test images is accounted for via the overscan region.
# <h3>Flats:</h3> quartz flats to characterize nonuniformity in CCD pixel sensitivity.
# <h3>Comparison lamps:</h3> Arc lamp exposures for wavelength calibration.
# <h3>Science/Comparison pairs:</h3> Object exposures and the corresponding comparison lamps.
#
# <h3>Initialization setup:</h3>
#
# `SAMOSNight(obsid=SAMOS_obsid,
#             raw_data_dir=raw_data_dir,
#             proc_dir=proc_dir,
#             ignore_bias=True)`
#
#
#
# #### Params:
# `obsid` the observation ID corresponding to the SAMOS data you want to reduce (not necessary currently, but will be implemented in the future) \
# `raw_data_dir` directory containing the raw observation data (for testing purposes) \
# `proc_dir` directory for storage of pipeline results \
# `ignore_bias` whether or not to ignore bias frames for correction (set to true because of overscan region in test data)

# %%
from SAMOS_DRP.SAMOS_NIGHT import SAMOSNight

#LOG_FILENAME = 'testing_DRP.log'

#if os.path.exists(LOG_FILENAME):
#    os.remove(LOG_FILENAME)

raw_data_dir = os.path.join(os.path.abspath('../'),'UNCOMP_GDMN_DATA')
    
#logging.basicConfig(filename=LOG_FILENAME,level=logging.DEBUG)
obsid = 'QUARANTINE'
GDMN_Night1 = SAMOSNight(obsid=obsid,
                         raw_data_dir=raw_data_dir,
                         proc_dir=os.path.join(os.getcwd(),obsid),
                         LOG_FILENAME='logfile',
                         ignore_bias=True) #setup
GDMN_Night1() #call
# Out:
# the pipeline is sorting your buckets
# True
# {'obsid': 'QUARANTINE', 'data_path': '/Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/UNCOMP_GDMN_DATA', 'gain': 2.06, 'rdnoise': 3.99, 'ccdsum': '1 1', 'empty_bucket': True, 'bias_buckets': None, 'flat_buckets': None, 'comp_buckets': None, 'targ_buckets': None, 'spec_buckets': None, 'slit_buckets': None, 'fits_slit_locs': None, 'sunset_time': None, 'sunrise_time': None, 'evening_twilight': None, 'morning_twilight': None, 'header_keys': ['naxis', 'date', 'slit', 'date-obs', 'obstype', 'object', 'exptime', 'obsra', 'obsdec', 'grating', 'cam_targ', 'grt_targ', 'filter', 'filter2', 'gain', 'rdnoise', 'ccdsum', 'wavmode']}
# added flat bucket                          file  naxis        date                 slit  \
# 0  psg_140319_210352_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 1  psg_140319_210620_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 2  psg_140319_210744_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 3  psg_140319_210907_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 4  psg_140319_211031_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 5  psg_140319_211154_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 6  psg_140319_211318_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 7  psg_140319_211442_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 8  psg_140319_211605_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 9  psg_140319_211729_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
#
#                   date-obs obstype object  exptime         obsra  \
# 0  2014-03-19T21:03:52.430    FLAT  qflat      2.0  04:13:24.164
# 1  2014-03-19T21:06:20.720    FLAT  qflat      2.0  04:13:24.164
# 2  2014-03-19T21:07:44.260    FLAT  qflat      2.0  04:13:24.164
# 3  2014-03-19T21:09:07.800    FLAT  qflat      2.0  04:13:24.164
# 4  2014-03-19T21:10:31.350    FLAT  qflat      2.0  04:13:24.164
# 5  2014-03-19T21:11:54.890    FLAT  qflat      2.0  04:13:24.164
# 6  2014-03-19T21:13:18.510    FLAT  qflat      2.0  04:13:24.164
# 7  2014-03-19T21:14:42.320    FLAT  qflat      2.0  04:13:24.164
# 8  2014-03-19T21:16:05.840    FLAT  qflat      2.0  04:13:24.164
# 9  2014-03-19T21:17:29.430    FLAT  qflat      2.0  04:13:24.164
#
#           obsdec  ... cam_targ  grt_targ       filter filter2  gain  rdnoise  \
# 0  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 1  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 2  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 3  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 4  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 5  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 6  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 7  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 8  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 9  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
#
#    ccdsum wavmode      radeg      decdeg
# 0     1 1     NaN  63.35 deg  -30.23 deg
# 1     1 1     NaN  63.35 deg  -30.23 deg
# 2     1 1     NaN  63.35 deg  -30.23 deg
# 3     1 1     NaN  63.35 deg  -30.23 deg
# 4     1 1     NaN  63.35 deg  -30.23 deg
# 5     1 1     NaN  63.35 deg  -30.23 deg
# 6     1 1     NaN  63.35 deg  -30.23 deg
# 7     1 1     NaN  63.35 deg  -30.23 deg
# 8     1 1     NaN  63.35 deg  -30.23 deg
# 9     1 1     NaN  63.35 deg  -30.23 deg
#
# [10 rows x 21 columns]
# [<class 'SAMOS_DRP.DataBucket.DataBucket'>
#  SAMOS Observation ID: QUARANTINE
#  Data Directory: /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/UNCOMP_GDMN_DATA
#  Gain: 2.06
#  Readout Noise: 3.99
#  ccdsum: 1 1
#  Is Empty: False
#
#  Bucket Grouping Information
#
#  (small buckets inside bigger bucekts!)
#  BIAS Group:
#    Group is Empty
#  FLATs Group:
#  Files in BUCKET
#    psg_140319_210352_fri.fits
#    psg_140319_210620_fri.fits
#    psg_140319_210744_fri.fits
#    psg_140319_210907_fri.fits
#    psg_140319_211031_fri.fits
#    psg_140319_211154_fri.fits
#    psg_140319_211318_fri.fits
#    psg_140319_211442_fri.fits
#    psg_140319_211605_fri.fits
#    psg_140319_211729_fri.fits
#  COMP Group:
#  Files in BUCKET
#    psg_140320_005007_cri.fits
#    psg_140320_005319_cri.fits
#    psg_140320_005443_cri.fits
#    psg_140320_005607_cri.fits
#    psg_140320_005731_cri.fits
#    psg_140320_005854_cri.fits
#    psg_140320_010018_cri.fits
#    psg_140320_010142_cri.fits
#    psg_140320_010305_cri.fits
#    psg_140320_010429_cri.fits
#    psg_140320_010553_cri.fits
#  SPEC Group
#  Files in BUCKET
#    psg_140319_235651_ori.fits
#    psg_140320_001436_ori.fits
#    psg_140320_003057_ori.fits
#    psg_140320_005007_cri.fits
#    psg_140320_005319_cri.fits
#    psg_140320_005443_cri.fits
#    psg_140320_005607_cri.fits
#    psg_140320_005731_cri.fits
#    psg_140320_005854_cri.fits
#    psg_140320_010018_cri.fits
#    psg_140320_010142_cri.fits
#    psg_140320_010305_cri.fits
#    psg_140320_010429_cri.fits
#    psg_140320_010553_cri.fits]

# %% [markdown]
# # CCD Processing

# %%
GDMN_Night1.data_buckets.fits_slit_locs

# %%
from SAMOS_DRP.ImageProcessor import ImageProcessor

GDMN_N1_ccproc = ImageProcessor(GDMN_Night1)
GDMN_N1_ccproc()
# Out:
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/UNCOMP_GDMN_DATA
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]

# %% [markdown]
# # Slit Tracing and Extraction
#
# This step is responsible for identifying the slits in the flat corrected images.

# %%
#reload(SAMOS_DRP.SlitBuckets)
from SAMOS_DRP.SlitBuckets import SlitBuckets


GDMN_N1_slits = SlitBuckets(GDMN_N1_ccproc)
GDMN_N1_slits()
# Out:
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# number of cols: 4060.000000
# number of rows: 1896.000000
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# number of cols: 4060.000000
# number of rows: 1896.000000

# %%
GDMN_N1_slits.combined_bucket
# Out:
#                                               file  naxis        date  \
# 0  fto_combined_orionfield-2_400_01-2-0000_01.fits      2  2014-03-19
# 0          fto_combined_HgAr_400_01-2-0000_01.fits      2  2014-03-20
#
#                   slit                 date-obs obstype         object  \
# 0  Ori0B1-field2-0000R  2014-03-19T23:56:51.590  OBJECT  orion field-2
# 0  Ori0B1-field2-0000R  2014-03-20T00:50:07.940    COMP           HgAr
#
#    exptime         obsra        obsdec  ... cam_targ  grt_targ       filter  \
# 0    900.0  05:31:44.872  -2:03:03.305  ...     16.1       7.5  <NO FILTER>
# 0      5.0  05:31:44.872  -2:03:03.305  ...     16.1       7.5  <NO FILTER>
#
#   filter2  gain  rdnoise  ccdsum wavmode      radeg     decdeg
# 0   GG455  2.06     3.99     1 1     NaN  82.94 deg  -2.05 deg
# 0   GG455  2.06     3.99     1 1     NaN  82.94 deg  -2.05 deg
#
# [2 rows x 21 columns]

# %%
#reload(SAMOS_DRP.DoWavecal)


GDMN_N1_wavecals = WaveCalBuckets(GDMN_N1_slits)

GDMN_N1_wavecals()
# Out:
# reference lamp location: /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/comp_refs
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s1_fto_combined_orionfield-2_400_01-2-0000_01.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s1_fto_combined_HgAr_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws1_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws1_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# s1_fto_combined_orionfield-2_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws1_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws1_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s2_fto_combined_orionfield-2_400_01-2-0000_01.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s2_fto_combined_HgAr_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws2_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws2_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# s2_fto_combined_orionfield-2_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws2_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws2_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s3_fto_combined_orionfield-2_400_01-2-0000_01.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s3_fto_combined_HgAr_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws3_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws3_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# s3_fto_combined_orionfield-2_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws3_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws3_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s4_fto_combined_orionfield-2_400_01-2-0000_01.fits
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# s4_fto_combined_HgAr_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws4_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws4_fto_combined_HgAr_400_01-2-0000_01_ws_1.fits
# s4_fto_combined_orionfield-2_400_01-2-0000_01.fits /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws4_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/jupyterNB_tutorial/testing/ws4_fto_combined_orionfield-2_400_01-2-0000_01_ws_1.fits
