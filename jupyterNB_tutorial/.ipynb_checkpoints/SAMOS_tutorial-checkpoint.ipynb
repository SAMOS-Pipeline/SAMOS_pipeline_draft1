# %%
# -*- coding: utf8 -*-
import sys
sys.path.insert(0,'../')

# %%
import os
import json
from astropy.io import fits
from astropy import units
import glob
import pandas as pd
import numpy as np
import ccdproc
from ccdproc import CCDData
import warnings
warnings.filterwarnings('ignore')
import logging
import argparse
import logging
from importlib import reload
from SAMOS_DRP.SAMOS_NIGHT import SAMOSNight
from SAMOS_DRP.ImageProcessor import ImageProcessor
from SAMOS_DRP.SAMOSHelpers import load_bucket_status,save_bucket_status
from SAMOS_DRP.SlitBuckets import SlitBuckets
from SAMOS_DRP.Spectroscopy.wavelength import WavelengthCalibration

LOG_FILENAME = 'testing_DRP.log'
if os.path.exists(LOG_FILENAME):
    os.remove(LOG_FILENAME)
    
logging.basicConfig(filename=LOG_FILENAME,level=logging.DEBUG)
GDMN_Night1 = SAMOSNight(obsid='testing_020720',raw_data_dir='../UNCOMP_GDMN_DATA/',
                         proc_dir='testing_020720_processing/',ignore_bias=True)
GDMN_Night1()
# Out:
# ../UNCOMP_GDMN_DATA/
# True
# {'obsid': 'testing_020720', 'data_path': '../UNCOMP_GDMN_DATA/', 'gain': 2.06, 'rdnoise': 3.99, 'ccdsum': '1 1', 'empty_bucket': True, 'bias_buckets': None, 'flat_buckets': None, 'comp_buckets': None, 'targ_buckets': None, 'spec_buckets': None, 'slit_buckets': None, 'fits_slit_locs': None, 'sunset_time': None, 'sunrise_time': None, 'evening_twilight': None, 'morning_twilight': None, 'header_keys': ['naxis', 'date', 'slit', 'date-obs', 'obstype', 'object', 'exptime', 'obsra', 'obsdec', 'grating', 'cam_targ', 'grt_targ', 'filter', 'filter2', 'gain', 'rdnoise', 'ccdsum', 'wavmode']}
# added flat bucket                           file  naxis        date             slit  \
# 10  psg_140319_202411_fri.fits      2  2014-03-19  0.84" long slit
# 11  psg_140319_202602_fri.fits      2  2014-03-19  0.84" long slit
# 12  psg_140319_202754_fri.fits      2  2014-03-19  0.84" long slit
# 13  psg_140319_202945_fri.fits      2  2014-03-19  0.84" long slit
# 14  psg_140319_203137_fri.fits      2  2014-03-19  0.84" long slit
# 15  psg_140319_203328_fri.fits      2  2014-03-19  0.84" long slit
# 16  psg_140319_203520_fri.fits      2  2014-03-19  0.84" long slit
# 17  psg_140319_203712_fri.fits      2  2014-03-19  0.84" long slit
# 18  psg_140319_203904_fri.fits      2  2014-03-19  0.84" long slit
# 19  psg_140319_204055_fri.fits      2  2014-03-19  0.84" long slit
#
#                    date-obs obstype object  exptime         obsra  \
# 10  2014-03-19T20:24:11.120    FLAT  qflat     30.0  07:06:51.059
# 11  2014-03-19T20:26:02.640    FLAT  qflat     30.0  07:06:51.059
# 12  2014-03-19T20:27:54.170    FLAT  qflat     30.0  07:06:51.059
# 13  2014-03-19T20:29:45.760    FLAT  qflat     30.0  07:06:51.059
# 14  2014-03-19T20:31:37.370    FLAT  qflat     30.0  07:06:51.059
# 15  2014-03-19T20:33:28.930    FLAT  qflat     30.0  07:06:51.059
# 16  2014-03-19T20:35:20.510    FLAT  qflat     30.0  07:06:51.059
# 17  2014-03-19T20:37:12.190    FLAT  qflat     30.0  07:06:51.059
# 18  2014-03-19T20:39:04.430    FLAT  qflat     30.0  07:06:51.059
# 19  2014-03-19T20:40:55.960    FLAT  qflat     30.0  07:06:51.059
#
#            obsdec  ... cam_targ  grt_targ       filter      filter2  gain  \
# 10  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 11  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 12  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 13  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 14  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 15  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 16  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 17  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 18  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 19  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
#
#     rdnoise  ccdsum wavmode       radeg      decdeg
# 10     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 11     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 12     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 13     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 14     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 15     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 16     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 17     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 18     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 19     3.99     1 1     NaN  106.71 deg  -17.64 deg
#
# [10 rows x 21 columns]
# added flat bucket                          file  naxis        date             slit  \
# 3  psg_140319_201303_fri.fits      2  2014-03-19  0.84" long slit
# 4  psg_140319_201432_fri.fits      2  2014-03-19  0.84" long slit
# 5  psg_140319_201602_fri.fits      2  2014-03-19  0.84" long slit
# 6  psg_140319_201731_fri.fits      2  2014-03-19  0.84" long slit
# 7  psg_140319_201901_fri.fits      2  2014-03-19  0.84" long slit
# 8  psg_140319_202030_fri.fits      2  2014-03-19  0.84" long slit
# 9  psg_140319_202200_fri.fits      2  2014-03-19  0.84" long slit
#
#                   date-obs obstype object  exptime         obsra  \
# 3  2014-03-19T20:13:03.290    FLAT  qflat      8.0  07:06:51.059
# 4  2014-03-19T20:14:32.770    FLAT  qflat      8.0  07:06:51.059
# 5  2014-03-19T20:16:02.330    FLAT  qflat      8.0  07:06:51.059
# 6  2014-03-19T20:17:31.850    FLAT  qflat      8.0  07:06:51.059
# 7  2014-03-19T20:19:01.400    FLAT  qflat      8.0  07:06:51.059
# 8  2014-03-19T20:20:30.950    FLAT  qflat      8.0  07:06:51.059
# 9  2014-03-19T20:22:00.530    FLAT  qflat      8.0  07:06:51.059
#
#           obsdec  ... cam_targ  grt_targ       filter      filter2  gain  \
# 3  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 4  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 5  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 6  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 7  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 8  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 9  -17:38:31.542  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
#
#    rdnoise  ccdsum wavmode       radeg      decdeg
# 3     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 4     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 5     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 6     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 7     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 8     3.99     1 1     NaN  106.71 deg  -17.64 deg
# 9     3.99     1 1     NaN  106.71 deg  -17.64 deg
#
# [7 rows x 21 columns]
# added flat bucket                          file  naxis        date             slit  \
# 0  psg_140319_200834_fri.fits      2  2014-03-19  0.84" long slit
# 1  psg_140319_201004_fri.fits      2  2014-03-19  0.84" long slit
# 2  psg_140319_201133_fri.fits      2  2014-03-19  0.84" long slit
#
#                   date-obs obstype object  exptime         obsra  \
# 0  2014-03-19T20:08:34.400    FLAT  qflat      8.0  16:20:29.062
# 1  2014-03-19T20:10:04.160    FLAT  qflat      8.0  16:20:29.062
# 2  2014-03-19T20:11:33.660    FLAT  qflat      8.0  16:20:29.062
#
#           obsdec  ... cam_targ  grt_targ       filter      filter2  gain  \
# 0  -30:13:35.702  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 1  -30:13:35.702  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
# 2  -30:13:35.702  ...     17.0       7.0  <NO FILTER>  <NO FILTER>  2.06
#
#    rdnoise  ccdsum wavmode       radeg      decdeg
# 0     3.99     1 1     NaN  245.12 deg  -30.23 deg
# 1     3.99     1 1     NaN  245.12 deg  -30.23 deg
# 2     3.99     1 1     NaN  245.12 deg  -30.23 deg
#
# [3 rows x 21 columns]
# added flat bucket                           file  naxis        date                 slit  \
# 31  psg_140319_211955_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 32  psg_140319_212340_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 33  psg_140319_212542_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 34  psg_140319_212744_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 35  psg_140319_212945_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 36  psg_140319_213147_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 37  psg_140319_213348_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 38  psg_140319_213550_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 39  psg_140319_213752_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 40  psg_140319_213953_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 41  psg_140319_214155_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
#
#                    date-obs obstype object  exptime         obsra  \
# 31  2014-03-19T21:19:55.140    FLAT  qflat      8.0  04:13:24.164
# 32  2014-03-19T21:23:40.890    FLAT  qflat     40.0  04:13:24.164
# 33  2014-03-19T21:25:42.680    FLAT  qflat     40.0  04:13:24.164
# 34  2014-03-19T21:27:44.260    FLAT  qflat     40.0  04:13:24.164
# 35  2014-03-19T21:29:45.820    FLAT  qflat     40.0  04:13:24.164
# 36  2014-03-19T21:31:47.380    FLAT  qflat     40.0  04:13:24.164
# 37  2014-03-19T21:33:48.890    FLAT  qflat     40.0  04:13:24.164
# 38  2014-03-19T21:35:50.440    FLAT  qflat     40.0  04:13:24.164
# 39  2014-03-19T21:37:52.010    FLAT  qflat     40.0  04:13:24.164
# 40  2014-03-19T21:39:53.590    FLAT  qflat     40.0  04:13:24.164
# 41  2014-03-19T21:41:55.160    FLAT  qflat     40.0  04:13:24.164
#
#            obsdec  ... cam_targ  grt_targ       filter filter2  gain  rdnoise  \
# 31  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 32  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 33  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 34  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 35  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 36  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 37  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 38  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 39  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 40  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 41  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
#
#     ccdsum wavmode      radeg      decdeg
# 31     1 1     NaN  63.35 deg  -30.23 deg
# 32     1 1     NaN  63.35 deg  -30.23 deg
# 33     1 1     NaN  63.35 deg  -30.23 deg
# 34     1 1     NaN  63.35 deg  -30.23 deg
# 35     1 1     NaN  63.35 deg  -30.23 deg
# 36     1 1     NaN  63.35 deg  -30.23 deg
# 37     1 1     NaN  63.35 deg  -30.23 deg
# 38     1 1     NaN  63.35 deg  -30.23 deg
# 39     1 1     NaN  63.35 deg  -30.23 deg
# 40     1 1     NaN  63.35 deg  -30.23 deg
# 41     1 1     NaN  63.35 deg  -30.23 deg
#
# [11 rows x 21 columns]
# added flat bucket                           file  naxis        date                 slit  \
# 20  psg_140319_210146_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 21  psg_140319_210352_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 22  psg_140319_210620_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 23  psg_140319_210744_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 24  psg_140319_210907_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 25  psg_140319_211031_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 26  psg_140319_211154_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 27  psg_140319_211318_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 28  psg_140319_211442_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 29  psg_140319_211605_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
# 30  psg_140319_211729_fri.fits      2  2014-03-19  Ori0B1-field2-0000R
#
#                    date-obs obstype object  exptime         obsra  \
# 20  2014-03-19T21:01:46.020    FLAT  qflat      2.0  04:13:24.164
# 21  2014-03-19T21:03:52.430    FLAT  qflat      2.0  04:13:24.164
# 22  2014-03-19T21:06:20.720    FLAT  qflat      2.0  04:13:24.164
# 23  2014-03-19T21:07:44.260    FLAT  qflat      2.0  04:13:24.164
# 24  2014-03-19T21:09:07.800    FLAT  qflat      2.0  04:13:24.164
# 25  2014-03-19T21:10:31.350    FLAT  qflat      2.0  04:13:24.164
# 26  2014-03-19T21:11:54.890    FLAT  qflat      2.0  04:13:24.164
# 27  2014-03-19T21:13:18.510    FLAT  qflat      2.0  04:13:24.164
# 28  2014-03-19T21:14:42.320    FLAT  qflat      2.0  04:13:24.164
# 29  2014-03-19T21:16:05.840    FLAT  qflat      2.0  04:13:24.164
# 30  2014-03-19T21:17:29.430    FLAT  qflat      2.0  04:13:24.164
#
#            obsdec  ... cam_targ  grt_targ       filter filter2  gain  rdnoise  \
# 20  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 21  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 22  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 23  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 24  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 25  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 26  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 27  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 28  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 29  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
# 30  -30:13:35.702  ...     16.1       7.5  <NO FILTER>   GG455  2.06     3.99
#
#     ccdsum wavmode      radeg      decdeg
# 20     1 1     NaN  63.35 deg  -30.23 deg
# 21     1 1     NaN  63.35 deg  -30.23 deg
# 22     1 1     NaN  63.35 deg  -30.23 deg
# 23     1 1     NaN  63.35 deg  -30.23 deg
# 24     1 1     NaN  63.35 deg  -30.23 deg
# 25     1 1     NaN  63.35 deg  -30.23 deg
# 26     1 1     NaN  63.35 deg  -30.23 deg
# 27     1 1     NaN  63.35 deg  -30.23 deg
# 28     1 1     NaN  63.35 deg  -30.23 deg
# 29     1 1     NaN  63.35 deg  -30.23 deg
# 30     1 1     NaN  63.35 deg  -30.23 deg
#
# [11 rows x 21 columns]
# [<class 'SAMOS_DRP.DataBucket.DataBucket'>
#  SAMOS Observation ID: testing_020720
#  Data Directory: ../UNCOMP_GDMN_DATA/
#  Gain: 2.06
#  Readout Noise: 3.99
#  ccdsum: 1 1
#  Is Empty: False
#
#  Bucket Grouping Information
#
#  (small buckets inside bigger bucekts!)
#  BIAS Group:
#    Group is Empty
#  FLATs Group:
#  Files in BUCKET 1
#    psg_140319_202411_fri.fits
#    psg_140319_202602_fri.fits
#    psg_140319_202754_fri.fits
#    psg_140319_202945_fri.fits
#    psg_140319_203137_fri.fits
#    psg_140319_203328_fri.fits
#    psg_140319_203520_fri.fits
#    psg_140319_203712_fri.fits
#    psg_140319_203904_fri.fits
#    psg_140319_204055_fri.fits
#  Files in BUCKET 2
#    psg_140319_201303_fri.fits
#    psg_140319_201432_fri.fits
#    psg_140319_201602_fri.fits
#    psg_140319_201731_fri.fits
#    psg_140319_201901_fri.fits
#    psg_140319_202030_fri.fits
#    psg_140319_202200_fri.fits
#  Files in BUCKET 3
#    psg_140319_200834_fri.fits
#    psg_140319_201004_fri.fits
#    psg_140319_201133_fri.fits
#  Files in BUCKET 4
#    psg_140319_211955_fri.fits
#    psg_140319_212340_fri.fits
#    psg_140319_212542_fri.fits
#    psg_140319_212744_fri.fits
#    psg_140319_212945_fri.fits
#    psg_140319_213147_fri.fits
#    psg_140319_213348_fri.fits
#    psg_140319_213550_fri.fits
#    psg_140319_213752_fri.fits
#    psg_140319_213953_fri.fits
#    psg_140319_214155_fri.fits
#  Files in BUCKET 5
#    psg_140319_210146_fri.fits
#    psg_140319_210352_fri.fits
#    psg_140319_210620_fri.fits
#    psg_140319_210744_fri.fits
#    psg_140319_210907_fri.fits
#    psg_140319_211031_fri.fits
#    psg_140319_211154_fri.fits
#    psg_140319_211318_fri.fits
#    psg_140319_211442_fri.fits
#    psg_140319_211605_fri.fits
#    psg_140319_211729_fri.fits
#  COMP Group:
#  Files in BUCKET 1
#  Files in BUCKET 2
#    psg_140320_005007_cri.fits
#    psg_140320_005319_cri.fits
#    psg_140320_005443_cri.fits
#    psg_140320_005607_cri.fits
#    psg_140320_005731_cri.fits
#    psg_140320_005854_cri.fits
#    psg_140320_010018_cri.fits
#    psg_140320_010142_cri.fits
#    psg_140320_010305_cri.fits
#    psg_140320_010429_cri.fits
#    psg_140320_010553_cri.fits
#  SPEC Group
#  Files in BUCKET 1
#    psg_140319_232920_ori.fits
#    psg_140319_233421_ori.fits
#  Files in BUCKET 2
#    psg_140319_235651_ori.fits
#    psg_140320_001436_ori.fits
#    psg_140320_003057_ori.fits
#    psg_140320_005007_cri.fits
#    psg_140320_005319_cri.fits
#    psg_140320_005443_cri.fits
#    psg_140320_005607_cri.fits
#    psg_140320_005731_cri.fits
#    psg_140320_005854_cri.fits
#    psg_140320_010018_cri.fits
#    psg_140320_010142_cri.fits
#    psg_140320_010305_cri.fits
#    psg_140320_010429_cri.fits
#    psg_140320_010553_cri.fits]

# %%
GDMN_N1_ccproc = ImageProcessor(GDMN_Night1)
GDMN_N1_ccproc()
# Out:
# ../UNCOMP_GDMN_DATA/
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
# INFO: using the unit adu passed to the FITS reader instead of the unit adu in the FITS file. [astropy.nddata.ccddata]
#                           file  naxis        date                 slit  \
# 62  psg_140319_232920_ori.fits      2  2014-03-19  Ori0B1-field2-0000R
# 63  psg_140319_233421_ori.fits      2  2014-03-19  Ori0B1-field2-0000R
#
#                    date-obs obstype         object  exptime         obsra  \
# 62  2014-03-19T23:29:20.630  OBJECT  orion field-2     20.0  05:31:44.872
# 63  2014-03-19T23:34:21.420  OBJECT  orion field-2     30.0  05:31:44.872
#
#           obsdec  ... cam_targ  grt_targ       filter filter2  gain  rdnoise  \
# 62  -2:03:03.305  ...      0.0     0.661  <NO FILTER>   GG455  2.06     3.99
# 63  -2:03:03.305  ...      0.0     0.661  <NO FILTER>   GG455  2.06     3.99
#
#     ccdsum wavmode      radeg     decdeg
# 62     1 1     NaN  82.94 deg  -2.05 deg
# 63     1 1     NaN  82.94 deg  -2.05 deg
#
# [2 rows x 21 columns]

# %%
GDMN_N1_slits = SlitBuckets(GDMN_N1_ccproc)
GDMN_N1_slits()

# %%
from SAMOS_DRP.drp_mods import add_wcs_keys,read_fits
import SAMOS_DRP.Spectroscopy.wcs
import SAMOS_DRP.Spectroscopy.wavelength
#reload(SAMOS_DRP.Spectroscopy.wavelength)
#reload(SAMOS_DRP.Spectroscopy.wcs)
from SAMOS_DRP.Spectroscopy.wavelength import WavelengthCalibration
for slit in range(len(GDMN_N1_slits.slit_targs)):
    
    Tccd = read_fits(GDMN_N1_slits.slit_targs[slit])
    Cccd = read_fits(GDMN_N1_slits.slit_comps[slit])
    wcs_starg = add_wcs_keys(Tccd)
    wcs_scomp = add_wcs_keys(Cccd)
    wavecal = WavelengthCalibration()
    
    targ1D = CCDData(np.median(Tccd.data,axis=0),unit='adu')
    targ1D.header = wcs_starg.header.copy()
    comp1D = CCDData(np.median(Cccd.data,axis=0),unit='adu')
    comp1D.header = wcs_scomp.header.copy()
    boo = wavecal(ccd=targ1D,comp_list=[comp1D],save_data_to='.',reference_data='comp_refs',
                              object_number=1,plot_results=True,save_plots=True,plots=False)

# %%
from DRP_with_SQL.drp_mods import call_cosmic_rejection,read_fits,combine_data,add_wcs_keys,identify_targets
from DRP_with_SQL.drp_mods import trace_targets
from DRP_with_SQL.Spectroscopy.wavelength import WavelengthCalibration


ccd = read_fits('./testing_020720_processing/Ori0B1-field2-0000R/s1_fto_combined_orionfield-2_400_01-2-0000_01.fits')
compccd = read_fits('./testing_020720_processing/Ori0B1-field2-0000R/s1_fto_combined_HgAr_400_01-2-0000_01.fits')
#print(test_slits.slit_targs)
compccd = add_wcs_keys(ccd=compccd)
comp_ccd_list = [compccd]
#for comp in test_slits.slit_comps:
#    ccd = add_wcs_keys(ccd=ccd)
#    comp_ccd_list.append(ccd)

    
#print(ccd)
target_list = identify_targets(
    ccd=ccd,fit_model='gaussian',background_threshold=10,plots=True,nfind=1)
                        #background_threshold=background_threshold,
                        #nfind=self.args.max_n_targets,
        
#if len(target_list)>0:
#    trace_list = trace_targets(ccd=ccd,target_list=target_list,sampling_step=5,pol_deg=2,plots=True)

# %%
# %matplotlib inline
import DRP_with_SQL.drp_mods
reload(DRP_with_SQL.drp_mods)
import DRP_with_SQL.Spectroscopy.wcs
reload(DRP_with_SQL.Spectroscopy.wcs)
import DRP_with_SQL.Spectroscopy.wavelength
reload(DRP_with_SQL.Spectroscopy.wavelength)
from DRP_with_SQL.Spectroscopy.wavelength import WavelengthCalibration

wavecal = WavelengthCalibration()
#print(compccd[25,:].header['wavmode'])
#print(compccd.header.keys)
boo = wavecal(ccd=ccd[25,:],comp_list=[compccd[25,:]],save_data_to='.',reference_data='comp_refs',
                              object_number=1,output_prefix='test',plot_results=True,save_plots=True,plots=True)

# %%
import re
print(ccd.header['wavmode'])
re.sub('[a-zA-Z"_*]', '', ccd.header['slit'])
print(17*0.15)

# %%
import DRP_with_SQL
#reload(DRP_with_SQL.drp_mods)

from DRP_with_SQL.convenience_functions import image_snippet

master_flat = CCDData.read(master_flat_name)

x,y = identify_slits(master_flat=master_flat)


slits,trimsecs = cutout_slit(master_flat,x,y)

# %%
identify_slits(None)
i=1
for slit in slits:
    this_slit = np.asarray(slit)
    print(this_slit.shape)
    tany = this_slit[~np.isnan(this_slit).any(axis=1)]
    tall = this_slit[~np.isnan(this_slit).all(axis=1)]
    print(tany==tall)
    print("slit number {:d} {}".format(i,this_slit[~np.isnan(this_slit).any(axis=1)]))
    i+=1

# %%
"""rawimages = glob.glob("RAW_GDMN_DATA/psg_1403??_??????_???.fits.fz")
uncomp_dir = 'UNCOMP_GDMN_DATA/'
rawimages.sort()
uncomp_imgs =[]
for raw in rawimages:
    #test files are compressed, which can't be read by ImageFileCollection so
    #I have to save new versions of the fits files with only the relevant hdu
    uncomp_img_name = os.path.split(raw)[1][:-3]
    uncomp_path = '%s/%s'%(uncomp_dir,uncomp_img_name)
    ccd = CCDData.read(raw,unit=units.adu,hdu=1,hdu_mask=[1,0])
    copy = ccd.copy()

    copy.data = copy.data[0]
    copy.write(uncomp_path,overwrite=True)
    uncomp_imgs.append(uncomp_img_name)
"""

# %%
for sub_bucket in test_bucket.data_buckets.flat_buckets:
    sbucket_obstype = sub_bucket.obstype.unique()
    print(sub_bucket.columns)
    print(sbucket_obstype)

# %%
test_bucket.data_buckets.
