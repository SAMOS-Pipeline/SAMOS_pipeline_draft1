# %%
import sys
import os
#instert path to modules: WORKING_DIR/py_mods/
base_dir = os.path.split(os.getcwd())[0]
mods_dir = base_dir +'/py_mods/'
sys.path.insert(0,mods_dir)
print sys.path[0]
from InitializeSAMOS import initialize_SAMOS 
from OverscanAndTrim import overscan_and_trim
from NormDivFlats import norm_div_flats
from OutlineSlits import outline_slits
#from PyrafIdentify import pyraf_identify
#import PyrafTransform
#the above are the main modules and functions called by the pipeline.
# Out:
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/py_mods/
# Main working directory is: /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline

# %%
##INITIALIZATION##

data_dir = '2017-11-30'
mask = 'LMask2'
fuel_init = initialize_SAMOS(data_dir,mask)
# Out:
# Scanning /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30
#
# Found field image:
# ['ccd8152c1.fits', 'ccd8152c2.fits']
# Found flats:
# ['ccd8161c1.fits', 'ccd8161c2.fits', 'ccd8162c1.fits', 'ccd8162c2.fits', 'ccd8163c1.fits', 'ccd8163c2.fits']
# Found lamps:
# ['ccd8159c1.fits', 'ccd8159c2.fits', 'ccd8160c1.fits', 'ccd8160c2.fits']
# Found science:
# ['ccd8157c1.fits', 'ccd8157c2.fits', 'ccd8158c1.fits', 'ccd8158c2.fits']
# With exposure times:
# [900. 900. 900. 900.]
# Keeping science:
# ['ccd8157c1.fits', 'ccd8157c2.fits', 'ccd8158c1.fits', 'ccd8158c2.fits']
# 4 science frames read

# %%
##OVERSCAN AND TRIM##

'''
Step 2 collects the raw data sorted and stored in fuel_init.util._(data type)_.raw_files

- data are bias corrected and the overscan regions trimmed.
- individual chip images are stitched together, and cosmic rays cleaned.
-  saved as new fits files with updated headers

Results from this step stored in fuel_init.util.intermediate_dir, and the letter `b` appended to the file name.
'''
fuel_ost = overscan_and_trim(fuel_init)
# Out:
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8159c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8159c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28159c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28159c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8159c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8159c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28159c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28159c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8160c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8160c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28160c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28160c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8160c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8160c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28160c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28160c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8161c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8161c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28161c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28161c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8161c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8161c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28161c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28161c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8162c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8162c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28162c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28162c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8162c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8162c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28162c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28162c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8163c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8163c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28163c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28163c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8163c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8163c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28163c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28163c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8157c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8157c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28157c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28157c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8157c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8157c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28157c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28157c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8158c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8158c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28158c1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28158c1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8158c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8158c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28158c2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask28158c2.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8152c1.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask2fieldc1.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask2fieldc1.fits written.
# Working on /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LDSS3/2017-11-30/ccd8152c2.fits
# Writing /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask2fieldc2.fits
# /Volumes/DanaExternalMacbook/PhD_Thesis/SAMOS_Project/SAMOS_pipeline/LMask2/intermediates/bLMask2fieldc2.fits written.

# %%
for k in vars(fuel_init).items():
    key = k[0]
    try: 
        key_att = vars(k[1])
        print '%s: %s \n'%(key,[i[0] for i in key_att.items()])
    except TypeError:
        print '%s: %s \n'%(key,k[1])
# Out:
# util: ['science', 'intermediate_dir', 'arc', 'field', 'slitflat']
#
# input: ['field_filelist', 'arc_filelist', 'working_dir', 'mask_SMF', 'slit_position_file', 'slit_mask', 'flat_filelist', 'db_file', 'science_filelist']
#
# slits: []
#
# identify: ['linelist', 'lgfile', 'db', 'linelist_ext']
#
# instrument: ['default_dark', 'default_pixelflat', 'gr_angle', 'dewar', 'linear_disp', 'd_alignrot', 'linearity_correction', 'dref', 'instrument', 'epoch', 'camera', 'scale_arc_per_mm', 'default_badpixel_mask', 'ns', 'resolution_slit1arcsec', 'central_wavelength', 'default_arc', 'pixel_scale', 'dewoff', 'default_illumflat', 'date', 'celestial_dec', 'hangle', 'temp', 'gr_order', 'mask', 'filter', 'mode', 'trim_edges', 'readnoise', 'resolution', 'grism', 'celestial_ra', 'gain']
